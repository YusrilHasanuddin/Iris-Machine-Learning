# %% [markdown]
# # 1. Support Vector Machine (SVM)
# Key objective of SVM is to draw a hyperplane which separates the two classes optimally such that the margin is maximum between the hyperplane and the observations.
#
# Key parameters:
#
# - **C** – the penalty parameter, it helps in fitting the boundaries smoothly and appropriately, **default=1**;
# - **Kernel** – it must be one of **rbf/linear/poly/sigmoid/precomputed**, **default='rbf'** (*Radial Basis Function*). Choosing appropriate kernel will result in better model fit.

# %% [markdown]
# ## Exercise 1: Multivariate and multi-class SVM model
# First, we will load the **Iris** dataset from scikit-learn. Here, the third column represents the petal length, and the fourth column the petal width of the flower samples. The classes are already converted to integer labels where **0=Iris-Setosa**, **1=Iris-Versicolor**, **2=Iris-Virginica**.

# %%
import warnings
warnings.filterwarnings('ignore')

from matplotlib.colors import ListedColormap
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import datasets
import numpy as np
import pandas as pd
from sklearn import tree
from sklearn import metrics

iris = datasets.load_iris()
X = iris.data[:, [2, 3]]
y = iris.target
print('Class labels:', np.unique(y))

# Normalize data
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
sc.fit(X)
X = sc.transform(X)

# Split data into train and test part 
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)


# Build the model (SVC-Support Vector Classification)
from sklearn.svm import SVC
clf = SVC(kernel='linear', C=1.0, random_state=0)
clf.fit(X_train, y_train)

# Generate evaluation metrics
print('\nTrain - Accuracy :', metrics.accuracy_score(y_train, clf.predict(X_train)))
print('Train - Confusion matrix :\n', metrics.confusion_matrix(y_train, clf.predict(X_train)))
print('Train - classification report :\n', metrics.classification_report(y_train, clf.predict(X_train)))

print('\nTest - Accuracy :', metrics.accuracy_score(y_test, clf.predict(X_test)))
print('Test - Confusion matrix :\n', metrics.confusion_matrix(y_test, clf.predict(X_test)))
print('Test - classification report :\n', metrics.classification_report(y_test, clf.predict(X_test)))
# Out:
# Class labels: [0 1 2]
#
# Train - Accuracy : 0.9523809523809523
# Train - Confusion matrix :
#  [[34  0  0]
#  [ 0 30  2]
#  [ 0  3 36]]
# Train - classification report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        34
#            1       0.91      0.94      0.92        32
#            2       0.95      0.92      0.94        39
#
#     accuracy                           0.95       105
#    macro avg       0.95      0.95      0.95       105
# weighted avg       0.95      0.95      0.95       105
#
#
# Test - Accuracy : 0.9777777777777777
# Test - Confusion matrix :
#  [[16  0  0]
#  [ 0 17  1]
#  [ 0  0 11]]
# Test - classification report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        16
#            1       1.00      0.94      0.97        18
#            2       0.92      1.00      0.96        11
#
# ...

# %%
iris = datasets.load_iris()
y = iris.target
z = iris.data[:, [0, 1, 2, 3]]
print('Class labels:', np.unique(y))

# Normalize data
sc = StandardScaler()
sc.fit(z)
z = sc.transform(z)

# Split data into train and test part 
Z_train, Z_test, y_train1, y_test1 = train_test_split(z, y, test_size=0.3, random_state=1)

# Build the model (SVC-Support Vector Classification)
clf = SVC(kernel='linear', C=1.0, random_state=1)
clf.fit(Z_train, y_train1)

# Generate evaluation metrics
print('\nTrain - Accuracy :', metrics.accuracy_score(y_train1, clf.predict(Z_train)))
print('Train - Confusion matrix :\n', metrics.confusion_matrix(y_train1, clf.predict(Z_train)))
print('Train - classification report :\n', metrics.classification_report(y_train1, clf.predict(Z_train)))

print('\nTest - Accuracy :', metrics.accuracy_score(y_test1, clf.predict(Z_test)))
print('Test - Confusion matrix :\n', metrics.confusion_matrix(y_test1, clf.predict(Z_test)))
print('Test - classification report :\n', metrics.classification_report(y_test1, clf.predict(Z_test)))
# Out:
# Class labels: [0 1 2]
#
# Train - Accuracy : 0.9714285714285714
# Train - Confusion matrix :
#  [[36  0  0]
#  [ 0 30  2]
#  [ 0  1 36]]
# Train - classification report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        36
#            1       0.97      0.94      0.95        32
#            2       0.95      0.97      0.96        37
#
#     accuracy                           0.97       105
#    macro avg       0.97      0.97      0.97       105
# weighted avg       0.97      0.97      0.97       105
#
#
# Test - Accuracy : 0.9777777777777777
# Test - Confusion matrix :
#  [[14  0  0]
#  [ 0 17  1]
#  [ 0  0 13]]
# Test - classification report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            1       1.00      0.94      0.97        18
#            2       0.93      1.00      0.96        13
#
# ...

# %%
clf = SVC(C=1.0, random_state=2)
clf.fit(Z_train, y_train1)

# Generate evaluation metrics
print('\nTrain - Accuracy :', metrics.accuracy_score(y_train1, clf.predict(Z_train)))
print('Train - Confusion matrix :\n', metrics.confusion_matrix(y_train1, clf.predict(Z_train)))
print('Train - classification report :\n', metrics.classification_report(y_train1, clf.predict(Z_train)))

print('\nTest - Accuracy :', metrics.accuracy_score(y_test1, clf.predict(Z_test)))
print('Test - Confusion matrix :\n', metrics.confusion_matrix(y_test1, clf.predict(Z_test)))
print('Test - classification report :\n', metrics.classification_report(y_test1, clf.predict(Z_test)))
# Out:
# Train - Accuracy : 0.9809523809523809
# Train - Confusion matrix :
#  [[36  0  0]
#  [ 0 30  2]
#  [ 0  0 37]]
# Train - classification report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        36
#            1       1.00      0.94      0.97        32
#            2       0.95      1.00      0.97        37
#
#     accuracy                           0.98       105
#    macro avg       0.98      0.98      0.98       105
# weighted avg       0.98      0.98      0.98       105
#
#
# Test - Accuracy : 0.9555555555555556
# Test - Confusion matrix :
#  [[14  0  0]
#  [ 0 17  1]
#  [ 0  1 12]]
# Test - classification report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            1       0.94      0.94      0.94        18
#            2       0.92      0.92      0.92        13
#
#     accuracy                           0.96        45
# ...

# %%
clf = SVC(kernel='poly', C=1.0, random_state=3)
clf.fit(Z_train, y_train1)

# Generate evaluation metrics
print('\nTrain - Accuracy :', metrics.accuracy_score(y_train1, clf.predict(Z_train)))
print('Train - Confusion matrix :\n', metrics.confusion_matrix(y_train1, clf.predict(Z_train)))
print('Train - classification report :\n', metrics.classification_report(y_train1, clf.predict(Z_train)))

print('\nTest - Accuracy :', metrics.accuracy_score(y_test1, clf.predict(Z_test)))
print('Test - Confusion matrix :\n', metrics.confusion_matrix(y_test1, clf.predict(Z_test)))
print('Test - classification report :\n', metrics.classification_report(y_test1, clf.predict(Z_test)))
# Out:
# Train - Accuracy : 0.9142857142857143
# Train - Confusion matrix :
#  [[36  0  0]
#  [ 0 32  0]
#  [ 0  9 28]]
# Train - classification report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        36
#            1       0.78      1.00      0.88        32
#            2       1.00      0.76      0.86        37
#
#     accuracy                           0.91       105
#    macro avg       0.93      0.92      0.91       105
# weighted avg       0.93      0.91      0.91       105
#
#
# Test - Accuracy : 0.9777777777777777
# Test - Confusion matrix :
#  [[14  0  0]
#  [ 0 18  0]
#  [ 0  1 12]]
# Test - classification report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            1       0.95      1.00      0.97        18
#            2       1.00      0.92      0.96        13
#
#     accuracy                           0.98        45
# ...

# %%
clf = SVC(kernel='sigmoid', C=1.0, random_state=4)
clf.fit(Z_train, y_train1)

# Generate evaluation metrics
print('\nTrain - Accuracy :', metrics.accuracy_score(y_train1, clf.predict(Z_train)))
print('Train - Confusion matrix :\n', metrics.confusion_matrix(y_train1, clf.predict(Z_train)))
print('Train - classification report :\n', metrics.classification_report(y_train1, clf.predict(Z_train)))

print('\nTest - Accuracy :', metrics.accuracy_score(y_test1, clf.predict(Z_test)))
print('Test - Confusion matrix :\n', metrics.confusion_matrix(y_test1, clf.predict(Z_test)))
print('Test - classification report :\n', metrics.classification_report(y_test1, clf.predict(Z_test)))
# Out:
# Train - Accuracy : 0.9142857142857143
# Train - Confusion matrix :
#  [[36  0  0]
#  [ 0 24  8]
#  [ 0  1 36]]
# Train - classification report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        36
#            1       0.96      0.75      0.84        32
#            2       0.82      0.97      0.89        37
#
#     accuracy                           0.91       105
#    macro avg       0.93      0.91      0.91       105
# weighted avg       0.92      0.91      0.91       105
#
#
# Test - Accuracy : 0.9333333333333333
# Test - Confusion matrix :
#  [[14  0  0]
#  [ 0 15  3]
#  [ 0  0 13]]
# Test - classification report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            1       1.00      0.83      0.91        18
#            2       0.81      1.00      0.90        13
#
#     accuracy                           0.93        45
# ...

# %%
clf = SVC(kernel='linear', C=100.0, random_state=1)
clf.fit(Z_train, y_train1)

# Generate evaluation metrics
print('\nTrain - Accuracy :', metrics.accuracy_score(y_train1, clf.predict(Z_train)))
print('Train - Confusion matrix :\n', metrics.confusion_matrix(y_train1, clf.predict(Z_train)))
print('Train - classification report :\n', metrics.classification_report(y_train1, clf.predict(Z_train)))

print('\nTest - Accuracy :', metrics.accuracy_score(y_test1, clf.predict(Z_test)))
print('Test - Confusion matrix :\n', metrics.confusion_matrix(y_test1, clf.predict(Z_test)))
print('Test - classification report :\n', metrics.classification_report(y_test1, clf.predict(Z_test)))
# Out:
# Train - Accuracy : 0.9714285714285714
# Train - Confusion matrix :
#  [[36  0  0]
#  [ 0 30  2]
#  [ 0  1 36]]
# Train - classification report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        36
#            1       0.97      0.94      0.95        32
#            2       0.95      0.97      0.96        37
#
#     accuracy                           0.97       105
#    macro avg       0.97      0.97      0.97       105
# weighted avg       0.97      0.97      0.97       105
#
#
# Test - Accuracy : 0.9777777777777777
# Test - Confusion matrix :
#  [[14  0  0]
#  [ 0 17  1]
#  [ 0  0 13]]
# Test - classification report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            1       1.00      0.94      0.97        18
#            2       0.93      1.00      0.96        13
#
#     accuracy                           0.98        45
# ...

# %%
clf = SVC(kernel='linear', C=0.5, random_state=1)
clf.fit(Z_train, y_train1)

# Generate evaluation metrics
print('\nTrain - Accuracy :', metrics.accuracy_score(y_train1, clf.predict(Z_train)))
print('Train - Confusion matrix :\n', metrics.confusion_matrix(y_train1, clf.predict(Z_train)))
print('Train - classification report :\n', metrics.classification_report(y_train1, clf.predict(Z_train)))

print('\nTest - Accuracy :', metrics.accuracy_score(y_test1, clf.predict(Z_test)))
print('Test - Confusion matrix :\n', metrics.confusion_matrix(y_test1, clf.predict(Z_test)))
print('Test - classification report :\n', metrics.classification_report(y_test1, clf.predict(Z_test)))
# Out:
# Train - Accuracy : 0.9714285714285714
# Train - Confusion matrix :
#  [[36  0  0]
#  [ 0 30  2]
#  [ 0  1 36]]
# Train - classification report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        36
#            1       0.97      0.94      0.95        32
#            2       0.95      0.97      0.96        37
#
#     accuracy                           0.97       105
#    macro avg       0.97      0.97      0.97       105
# weighted avg       0.97      0.97      0.97       105
#
#
# Test - Accuracy : 0.9555555555555556
# Test - Confusion matrix :
#  [[14  0  0]
#  [ 0 17  1]
#  [ 0  1 12]]
# Test - classification report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            1       0.94      0.94      0.94        18
#            2       0.92      0.92      0.92        13
#
#     accuracy                           0.96        45
# ...

# %% [markdown]
# **Questions:**
# 1. How do you interpret the confusion matrices for the training and test datasets?
# 2. What is the purpose of data normalization?
# 3. You used only petal length and petal width in the model. Compare the results with a model based on all 4 features.
# 4. Build models and compare their accuracy for **C=1** and 3 different kernels.
# 5. Build models and compare their accuracy for the best kernel found in the previous task and 3 different values of a penalty parameter.
#
# **Answers:**

# %% [raw]
# 1. From the confusion matrix, we know that there is a miss prediction that the model occurs. From the training data, 5 data are mislabeled. From the test data, there are 1 mislabeled data. Therefore, we can conduct that our model is good because there is a decrease in mislabeled data.
# 2. To make all features into the same condition, such as from 0 - 1. By doing this, it can reduce data redundancy and improve data integrity.
# 3. The resulting accuracy from all 4 features is same for test data prediction, but there is a difference in result accuracy from train data. Result accuracy of 4 features of train data is much higher than only 2 features.
# 4. From 4 different model using all features, from best to worse accuracy are: (With same C = 1.0)
# -from the perspective of train data
# 1) rbf
# 2) linear
# 3) poly and sigmoid
# -from the perspective of test data:
# 1) poly and linear
# 2) rbf
# 3) sigmoid
# 5. Only from the perspective of test data using all features to make the model, using the linear kernel, the best accuracy comes from C >= 1.0.

# %% [markdown]
# # 2. K-Nearest Neighbors (K-NN)
# As the name suggests the algorithm works based on majority vote of its **K-Nearest Neighbors** class. **K** nearest neighbors for the unknown data point are identified based on the chosen distance measure, and the unknown point will be classified based on majority class among identified nearest data points class. The key drawback of **K-NN** is the complexity in searching the nearest neighbors for each sample.
#
# Things to remember:
#
# - Choose an odd **K** value for a 2 class problem.
# - **K** must not be a multiple of the number of classes.

# %% [markdown]
# ## Exercise 2: K-Nearest Neighbors model
# We use the same data set as in exercise 1.

# %%
import warnings
warnings.filterwarnings('ignore')

from matplotlib.colors import ListedColormap
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import datasets
import numpy as np
import pandas as pd
from sklearn import tree
from sklearn import metrics

iris = datasets.load_iris()
X = iris.data[:, [2, 3]]
y = iris.target
print('Class labels:', np.unique(y))

# Normalize data
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
sc.fit(X)
X = sc.transform(X)

# Split data into train and test part
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# Build the model
from sklearn.neighbors import KNeighborsClassifier
clf = KNeighborsClassifier(n_neighbors=5)
clf.fit(X_train, y_train)

# Generate evaluation metrics
print('\nTrain - Accuracy :', metrics.accuracy_score(y_train, clf.predict(X_train)))
print('Train - Confusion matrix :\n', metrics.confusion_matrix(y_train, clf.predict(X_train)))
print('Train - classification report :\n', metrics.classification_report(y_train, clf.predict(X_train)))

print('\nTest - Accuracy :', metrics.accuracy_score(y_test, clf.predict(X_test)))
print('Test - Confusion matrix :\n', metrics.confusion_matrix(y_test, clf.predict(X_test)))
print('Test - classification report :\n', metrics.classification_report(y_test, clf.predict(X_test)))
# Out:
# Class labels: [0 1 2]
#
# Train - Accuracy : 0.9523809523809523
# Train - Confusion matrix :
#  [[34  0  0]
#  [ 0 30  2]
#  [ 0  3 36]]
# Train - classification report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        34
#            1       0.91      0.94      0.92        32
#            2       0.95      0.92      0.94        39
#
#     accuracy                           0.95       105
#    macro avg       0.95      0.95      0.95       105
# weighted avg       0.95      0.95      0.95       105
#
#
# Test - Accuracy : 1.0
# Test - Confusion matrix :
#  [[16  0  0]
#  [ 0 18  0]
#  [ 0  0 11]]
# Test - classification report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        16
#            1       1.00      1.00      1.00        18
#            2       1.00      1.00      1.00        11
#
#     accuracy                           1.00        45
# ...

# %%
# Build the model
clf = KNeighborsClassifier(n_neighbors=5)
clf.fit(Z_train, y_train1)

# Generate evaluation metrics
print('\nTrain - Accuracy :', metrics.accuracy_score(y_train1, clf.predict(Z_train)))
print('Train - Confusion matrix :\n', metrics.confusion_matrix(y_train1, clf.predict(Z_train)))
print('Train - classification report :\n', metrics.classification_report(y_train1, clf.predict(Z_train)))

print('\nTest - Accuracy :', metrics.accuracy_score(y_test1, clf.predict(Z_test)))
print('Test - Confusion matrix :\n', metrics.confusion_matrix(y_test1, clf.predict(Z_test)))
print('Test - classification report :\n', metrics.classification_report(y_test1, clf.predict(Z_test)))
# Out:
# Train - Accuracy : 0.9714285714285714
# Train - Confusion matrix :
#  [[36  0  0]
#  [ 0 30  2]
#  [ 0  1 36]]
# Train - classification report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        36
#            1       0.97      0.94      0.95        32
#            2       0.95      0.97      0.96        37
#
#     accuracy                           0.97       105
#    macro avg       0.97      0.97      0.97       105
# weighted avg       0.97      0.97      0.97       105
#
#
# Test - Accuracy : 0.9555555555555556
# Test - Confusion matrix :
#  [[14  0  0]
#  [ 0 17  1]
#  [ 0  1 12]]
# Test - classification report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            1       0.94      0.94      0.94        18
#            2       0.92      0.92      0.92        13
#
#     accuracy                           0.96        45
# ...

# %%
clf = KNeighborsClassifier(n_neighbors=1)
clf.fit(X_train, y_train)

# Generate evaluation metrics
print('\nTrain - Accuracy :', metrics.accuracy_score(y_train, clf.predict(X_train)))
print('Train - Confusion matrix :\n', metrics.confusion_matrix(y_train, clf.predict(X_train)))
print('Train - classification report :\n', metrics.classification_report(y_train, clf.predict(X_train)))

print('\nTest - Accuracy :', metrics.accuracy_score(y_test, clf.predict(X_test)))
print('Test - Confusion matrix :\n', metrics.confusion_matrix(y_test, clf.predict(X_test)))
print('Test - classification report :\n', metrics.classification_report(y_test, clf.predict(X_test)))
# Out:
# Train - Accuracy : 0.9904761904761905
# Train - Confusion matrix :
#  [[34  0  0]
#  [ 0 31  1]
#  [ 0  0 39]]
# Train - classification report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        34
#            1       1.00      0.97      0.98        32
#            2       0.97      1.00      0.99        39
#
#     accuracy                           0.99       105
#    macro avg       0.99      0.99      0.99       105
# weighted avg       0.99      0.99      0.99       105
#
#
# Test - Accuracy : 0.9777777777777777
# Test - Confusion matrix :
#  [[16  0  0]
#  [ 0 17  1]
#  [ 0  0 11]]
# Test - classification report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        16
#            1       1.00      0.94      0.97        18
#            2       0.92      1.00      0.96        11
#
#     accuracy                           0.98        45
# ...

# %%
clf = KNeighborsClassifier(n_neighbors=10)
clf.fit(X_train, y_train)

# Generate evaluation metrics
print('\nTrain - Accuracy :', metrics.accuracy_score(y_train, clf.predict(X_train)))
print('Train - Confusion matrix :\n', metrics.confusion_matrix(y_train, clf.predict(X_train)))
print('Train - classification report :\n', metrics.classification_report(y_train, clf.predict(X_train)))

print('\nTest - Accuracy :', metrics.accuracy_score(y_test, clf.predict(X_test)))
print('Test - Confusion matrix :\n', metrics.confusion_matrix(y_test, clf.predict(X_test)))
print('Test - classification report :\n', metrics.classification_report(y_test, clf.predict(X_test)))
# Out:
# Train - Accuracy : 0.9619047619047619
# Train - Confusion matrix :
#  [[34  0  0]
#  [ 0 31  1]
#  [ 0  3 36]]
# Train - classification report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        34
#            1       0.91      0.97      0.94        32
#            2       0.97      0.92      0.95        39
#
#     accuracy                           0.96       105
#    macro avg       0.96      0.96      0.96       105
# weighted avg       0.96      0.96      0.96       105
#
#
# Test - Accuracy : 1.0
# Test - Confusion matrix :
#  [[16  0  0]
#  [ 0 18  0]
#  [ 0  0 11]]
# Test - classification report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        16
#            1       1.00      1.00      1.00        18
#            2       1.00      1.00      1.00        11
#
#     accuracy                           1.00        45
# ...

# %% [markdown]
# **Questions:**
# 1. Compare the accuracy of the K-NN model with that of the SVM model.
# 2. You used only petal length and petal width in the model. Compare the results with a model based on all 4 features.
# 3. Select 2 correct **K** values. One should be smaller than **5** and the other bigger. Build models for these **K** and compare their accuracy with the model accuracy for **K=5**.
#
# **Answers:**

# %% [raw]
# 1. The accuracy from test data is amazing because it reaches 100% accuracy. Therefore, we can say KNN is a better method to make this data model, rather than using SVM. However, the accuracy from train data is higher with SVM linear with C = 1.0, but in my opinion, it is better to have high accuracy on the test data rather than train data.
# 2. The accuracy from the model's test data using only petal length and petal width is higher than using all 4 features. From the previous meeting, we know that Sepal length does not have anything to do with this classification.
# 3. The best result accuracy from both train and test data is using the knn method with k-neighbors = 10. After that, k-neighbors = 5. As well, the worse one with k-neighbors = 1.

# %% [markdown]
# ## Exercise 3: K-NN model decision boundary

# %%
# An auxiliary function that will be used to plot the decision boundary.
def plot_decision_regions(X, y, classifier): 
    h = .02  # Step size in the mesh
    # Setup marker generator and color map
    markers = ('s', 'x', 'o', '^', 'v')
    colors = ('red', 'blue', 'lightgreen', 'gray', 'cyan')
    cmap = ListedColormap(colors[:len(np.unique(y))])

    # Plot the decision surface
    x1_min, x1_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    x2_min, x2_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx1, xx2 = np.meshgrid(np.arange(x1_min, x1_max, h),
                           np.arange(x2_min, x2_max, h))
    Z = classifier.predict(np.array([xx1.ravel(), xx2.ravel()]).T)
    Z = Z.reshape(xx1.shape)
    plt.contourf(xx1, xx2, Z, alpha=0.4, cmap=cmap)
    plt.xlim(xx1.min(), xx1.max())
    plt.ylim(xx2.min(), xx2.max())

    for idx, cl in enumerate(np.unique(y)):
        plt.scatter(x=X[y == cl, 0], y=X[y == cl, 1],
                    alpha=0.8, color=cmap(idx),
                    marker=markers[idx], label=cl)

# %%
# Load data
iris = datasets.load_iris()
X = iris.data[:, [2, 3]]
y = iris.target

# Build a K-NN model
clf = KNeighborsClassifier(n_neighbors=5)
clf.fit(X, y)

# Plot the decision boundary
plot_decision_regions(X, y, classifier=clf)
plt.xlabel('Petal length')
plt.ylabel('Petal width')
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()

# %%
clf = KNeighborsClassifier(n_neighbors=1)
clf.fit(X, y)

# Plot the decision boundary
plot_decision_regions(X, y, classifier=clf)
plt.xlabel('Petal length')
plt.ylabel('Petal width')
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()

# %%
clf = KNeighborsClassifier(n_neighbors=10)
clf.fit(X, y)

# Plot the decision boundary
plot_decision_regions(X, y, classifier=clf)
plt.xlabel('Petal length')
plt.ylabel('Petal width')
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Questions:**
# 1. Considering the decision boundary, which species of **Iris** are better separated and which are worse? Justify your answer.
# 2. Plot the decision boundaries for the two **K** values used in the previous exercise and compare them with the boundary for **K=5**.
#
# **Answers:**

# %% [raw]
# 1. The perfectly separated species is setosa with the other two species. The worse separation is between Virginia and Versicolor.
# 2. From the plot, we can conclude all of the models have perfectly classified for setosa species. But, for two other species, models are difficult to classify. In my opinion, using k-neighbors = 1 making the model more underfitting than using k-neighbors = 5 or 10.

# %% [markdown]
# # 3. Autoregressive Integrated Moving Average (ARIMA)
# Data points that are collected sequentially at a regular interval with association over a time period is termed as **time-series** data. A time-series data having the **mean** and **variance** as constant is called **stationary time-series**.
#
# Time-series tend to have a linear relationship between lagged variables and this is called as **autocorrelation**. Hence a time-series historic data can be modelled to forecast the future data points without involvement of any other independent variables. This process is generally known as **time-series forecasting**.

# %% [markdown]
# ## Exercise 4: Time-series decomposing
# First stage is creating a chart to see whether a **trend**, **cycle** and **seasonality** exists in the data set.

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline

from scipy import stats
import statsmodels.api as sm
from statsmodels.graphics.api import qqplot

from statsmodels.tsa.stattools import adfuller

# Functions to calculate MAE, RMSE
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Load data
df = pd.read_csv('TS.csv')
ts = pd.Series(list(df['Sales']), index=pd.to_datetime(df['Month'], format='%Y-%m'))

from statsmodels.tsa.seasonal import seasonal_decompose
decomposition = seasonal_decompose(ts)

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

plt.subplot(311)
plt.title('Time-series - decomposed')
plt.plot(ts, label = 'Original')
plt.legend(loc = 'best')

plt.subplot(312)
plt.plot(trend, label = 'Trend')
plt.legend(loc = 'best')

plt.subplot(313)
plt.plot(seasonal,label = 'Seasonality')
plt.legend(loc = 'best')
plt.tight_layout()

# %% [markdown]
# **Question:**
# 1. Based on the charts above assess whether a trend and seasonality in the data set exists. Justify your answer.
#
# **Answer:**

# %% [raw]
# 1. There are trends and seasonality in the data set. We can see in graph 2 (Trend) that trend is increasing. For seasonality, we can agree on graph 3 (Seasonality) there is a pattern in each year.

# %% [markdown]
# ## Exercise 5: Stationarize time-series
# Second stage is checking for stationarity of a time-series. If the series is non-stationary, the right operations must be performed to achieve stationarity.

# %% [markdown]
# **1. Checking for stationarity.**

# %%
s_test = adfuller(ts, autolag='AIC')
# Extract p-value from test results
print('p-value > 0.05 means data is non-stationary:', s_test[1])
# Out:
# p-value > 0.05 means data is non-stationary: 0.9888894205170052

# %% [markdown]
# **2. Application of a log transform.**

# %%
ts_log = np.log(ts)
ts_log.dropna(inplace = True)

moving_avg = ts_log.rolling(12).mean()
plt.plot(ts_log)
plt.title('Log vs Moving AVg')
plt.tick_params(axis = 'x', labelsize = 10)
plt.tick_params(axis = 'y', labelsize = 10)
plt.plot(moving_avg, color='red')
plt.tight_layout()
plt.show()

s_test = adfuller(ts_log, autolag = 'AIC')
print('p-value after log transform:', s_test[1])
# Out:
# p-value after log transform: 0.785310212484911

# %% [markdown]
# **3. Application of the 1-st order difference technique.**

# %%
ts_log_diff = ts_log - ts_log.shift()
ts_log_diff.dropna(inplace = True)

plt.title('First order difference')
plt.tick_params(axis = 'x', labelsize = 10)
plt.tick_params(axis = 'y', labelsize = 10)
plt.plot(ts_log_diff)
plt.show()

s_test = adfuller(ts_log_diff, autolag = 'AIC')
print('p-value after 1-st order difference:', s_test[1])
# Out:
# p-value after 1-st order difference: 0.02402539283987568

# %% [markdown]
# **Questions:**
# 1. What does it mean that the time-series is stationary?
# 2. Is the original time-series stationary? How was this fact checked?
# 3. What is the purpose for applying of the log transform and 1-st order difference operations? Please discuss the results of these operations based on the charts above.
# 4. Was it possible to obtain the stationarity of the time-series? On what basis can you say that?
#
# **Answers:**

# %% [raw]
# 1. It means there is no trend in the dataset. This means the data is neither increasing nor decreasing.
# 2. From the above dataset, we know that the data is not stationary because of p-value > 0.05.
# 3. By doing log transform, it can make data approximately conform to normality. We can look at the charts above, y-axis value is change to smaller numeric. We can also see the changes in p-value after log transform.
# 4. There is a possibility to obtain stationarity of the time-series if p-value <= 0.05.

# %% [markdown]
# ## Exercise 6: Find optimal parameters
# We determined that the log of time series requires at least one order differencing to stationarize. Now, in the third stage, we will plot **ACF** and **PACF** charts for first order log series. On this basis we can find the **p** and **q** parameters of the ARIMA model.

# %%
# ACF chart
sm.graphics.tsa.plot_acf(ts_log_diff.values.squeeze(), lags = 20)

# Draw 95% confidence interval line
plt.axhline(y = -1.96/np.sqrt(len(ts_log_diff)), linestyle = '--', color = 'gray')
plt.axhline(y = 1.96/np.sqrt(len(ts_log_diff)), linestyle = '--', color = 'gray')
plt.tick_params(labelsize = 10)
plt.xlabel('Lags')
plt.show()

# %% [markdown]
# The **ACF** plot has significant spikes at lags 1 and 2. On this basis we assume **q=2**.

# %%
# PACF chart
sm.graphics.tsa.plot_pacf(ts_log_diff, lags = 20)

# Draw 95% confidence interval line
plt.axhline(y = -1.96/np.sqrt(len(ts_log_diff)), linestyle = '--', color = 'gray')
plt.axhline(y = 1.96/np.sqrt(len(ts_log_diff)), linestyle = '--', color = 'gray')
plt.tick_params(labelsize = 10)
plt.xlabel('Lags')
plt.show()

# %% [markdown]
# The **PACF** plot has significant spikes at lags 1 and 2, meaning that all the higher-order autocorrelations are effectively explained by the lag-1 and lag-2 autocorrelation. On this basis we assume **p=2**.

# %% [markdown]
# **Question:**
# 1. The values in the ACF and PACF charts are alternately positive and negative. What does it mean?
#
# **Answer:**

# %% [raw]
# 1. It means there are Direct proportion and Inverse proportion for correlation.

# %% [markdown]
# ## Exercise 7: Model building and evaluation
# The values of the **p** and **q** parameters were found. On this basis we can start the fourth stage, which is the building and evaluation of the initial **ARIMA(2,0,2)** model.

# %%
import warnings
warnings.filterwarnings('ignore')

# Build model
model = sm.tsa.SARIMAX(ts_log, order = (2,0,2))
results_ARIMA = model.fit(disp = -1) 
ts_predict = results_ARIMA.predict()

# Plot of actual and predicted values
plt.title('ARIMA Prediction - order(2,0,2)')
plt.plot(ts_log, label = 'Actual')
plt.plot(ts_predict, 'r--', label = 'Predicted')
plt.xlabel('Year-Month')
plt.ylabel('Sales')
plt.legend(loc = 'best')
plt.show()

# disp controls the frequency of the output during the iterations, disp < 0 means no output.
results_ARIMA = model.fit(disp = -1)
ts_predict = results_ARIMA.predict()

# Evaluate model
print('AIC:', results_ARIMA.aic)
print('BIC:', results_ARIMA.bic)
print('Mean Absolute Error:', mean_absolute_error(ts_log.values, ts_predict.values))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(ts_log.values, ts_predict.values)))

# Check autocorrelation
print('Durbin-Watson statistic:', sm.stats.durbin_watson(results_ARIMA.resid.values))
# Out:
# AIC: 28.028722622773167
# BIC: 39.747749732041584
# Mean Absolute Error: 0.2798700102316855
# Root Mean Squared Error: 0.6305375079856635
# Durbin-Watson statistic: 1.308738671588488

# %% [markdown]
# Usual practice is to build several models with different **p** and **q** and select the one with the smallest value of **AIC**, **BIC**, **MAE** and **RMSE**. Now lets' increase **p** to **3** and see if there is any difference in result.

# %%
# Build model
model = sm.tsa.ARIMA(ts_log, order = (3,0,2))
results_ARIMA = model.fit(disp = -1) 
ts_predict = results_ARIMA.predict()

# Plot of actual and predicted values
plt.title('ARIMA Prediction - order(3,0,2)')
plt.plot(ts_log, label = 'Actual')
plt.plot(ts_predict, 'r--', label = 'Predicted')
plt.xlabel('Year-Month')
plt.ylabel('Sales')
plt.legend(loc = 'best')
plt.show()

# Evaluate model
print('AIC:', results_ARIMA.aic)
print('BIC:', results_ARIMA.bic)
print('Mean Absolute Error:', mean_absolute_error(ts_log.values, ts_predict.values))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(ts_log.values, ts_predict.values)))

# Check autocorrelation
print('Durbin-Watson statistic:', sm.stats.durbin_watson(results_ARIMA.resid.values))
# Out:
# AIC: -7.786725279653751
# BIC: 8.619912673322037
# Mean Absolute Error: 0.16726259014400863
# Root Mean Squared Error: 0.2161405380582603
# Durbin-Watson statistic: 2.519176262949236

# %% [markdown]
# **Questions:**
# 1. Compare the evaluation results of the **ARIMA(2,0,2)** and **ARIMA(3,0,2)** models. Which model is better in your opinion and why?
# 2. How should the Durbin-Watson statistic be interpreted?
#
# **Answers:**

# %% [raw]
# 1. We can say the better ARIMA model is ARIMA(3,0,2) model. Since the prediction is near fit to the actual value. Model ARIMA(2,0,2) is under predicting.

# %% [markdown]
# Let’s try it with first order differencing (**d=1**) to see if the model performance improves.

# %%
# Build model
model = sm.tsa.ARIMA(ts_log, order = (3,1,2))
results_ARIMA = model.fit(disp = -1) 
ts_predict = results_ARIMA.predict()

# Correction for difference 
predictions_ARIMA_diff = pd.Series(ts_predict, copy = True)
predictions_ARIMA_diff_cumsum = predictions_ARIMA_diff.cumsum()
predictions_ARIMA_log = pd.Series(ts_log[0], index = ts_log.index)
predictions_ARIMA_log = predictions_ARIMA_log.add(predictions_ARIMA_diff_cumsum, fill_value = 0)

# Plot of actual and predicted values
plt.title('ARIMA Prediction - order(3,1,2)')
plt.plot(ts_log, label = 'Actual')
plt.plot(predictions_ARIMA_log, 'r--', label = 'Predicted')
plt.xlabel('Year-Month')
plt.ylabel('Sales')
plt.legend(loc='best')
plt.show()

# Evaluate model
print('AIC:', results_ARIMA.aic)
print('BIC:', results_ARIMA.bic)
print('Mean Absolute Error:', mean_absolute_error(ts_log_diff.values, ts_predict.values))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(ts_log_diff.values, ts_predict.values)))

# Check autocorrelation
print('Durbin-Watson statistic:', sm.stats.durbin_watson(results_ARIMA.resid.values))
# Out:
# AIC: -35.41898773837741
# BIC: -19.10385435637309
# Mean Absolute Error: 0.1387653759311743
# Root Mean Squared Error: 0.18310243838910772
# Durbin-Watson statistic: 1.9411648613884036

# %% [markdown]
# In the chart above we can see that the model is over predicting at some places and **AIC** and **BIC** values are higher than for the previous model. Note: **AIC/BIC** can be positive or negative, however we should look at the absolute value of it for evaluation

# %% [markdown]
# **Question:**
# 1. Compare the evaluation results of the **ARIMA(3,0,2)** and **ARIMA(3,1,2)** models. Which model is better in your opinion and why?
#
# **Answer:**

# %% [raw]
# 1. We can say the better ARIMA model is ARIMA(3,0,2) model. Since the prediction is near fit to the actual value. Model ARIMA(3,1,2) is over predicting.

# %% [markdown]
# ## Exercise 8: Predicting the future values
# Below parameters (**p=3**, **d=0**, **q=2**) are giving the smaller values for evaluation metrics, so lets use them for the final model to predict the future values (for the year 1972).

# %%
# Final model
model = sm.tsa.ARIMA(ts_log, order = (3,0,2))
results_ARIMA = model.fit(disp = -1) 

# Predict future values
ts_predict = results_ARIMA.predict('1971-06-01', '1972-05-01')
plt.title('ARIMA Future Value Prediction - order(3,0,2)')
plt.plot(ts_log, label = 'Actual')
plt.plot(ts_predict, 'r--', label = 'Predicted')
plt.xlabel('Year-Month')
plt.ylabel('Sales')
plt.legend(loc = 'best')
plt.show()

# %% [markdown]
# **Question:**
# 1. What can you tell about the predicted sales for 1972?
#
# **Answer:**

# %% [raw]
# 1. We can say that in 1972, sales value is decreasing.
